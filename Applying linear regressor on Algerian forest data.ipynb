# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
from six.moves import urllib

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv("Algerian_forest.csv",header=1)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.shape
# Out:
# (246, 14)

# %%
df.head(125)
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 0                               01     06  2012           29   57   18      0
# 1                               02     06  2012           29   61   13    1.3
# 2                               03     06  2012           26   82   22   13.1
# 3                               04     06  2012           25   89   13    2.5
# 4                               05     06  2012           27   77   16      0
# ..                             ...    ...   ...          ...  ...  ...    ...
# 120                             29     09  2012           26   80   16    1.8
# 121                             30     09  2012           25   78   14    1.4
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
#
# ...

# %%
df.drop(df.index[122:124], inplace = True)

# %%
df.head(125)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
#
#        Classes
# 0    not fire
# ...

# %%
df =df.reset_index()

# %%
df
# Out:
#      index day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  \
# 0        0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1        1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2        2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3        3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4        4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2
# ..     ...  ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...
# 239    241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5
# 240    242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1
# 241    243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4
# 242    244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7
# 243    245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2
#
#       BUI  FWI     Classes
# 0     3.4  0.5   not fire
# ...

# %%
df.drop(['index'],axis =1, inplace=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df['region']='Bejaia'

# %%
df['region'][122:]='Sidi-Bel Abbes'

# %%
df.head(123)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
#
#        Classes            region
# ...

# %%
df.shape
# Out:
# (244, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  region       244 non-null    object
# dtypes: object(15)
# memory usage: 28.7+ KB

# %%
##as i will be applying linear regressor on this data so that i will drop the categoricl acolumns first

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes            region
# 0    0.5   not fire             Bejaia
# ...

# %%
##column names have some spaces, so we will rename them for convenience

# %%
df.rename(columns = {' RH':'RH'}, inplace = True)
df.rename(columns = {' Ws':'Ws'}, inplace = True)
df.rename(columns = {'Rain ':'Rain'}, inplace = True)
df.rename(columns = {'Classes  ':'Classes'}, inplace = True)

# %%
df.drop(['Classes','region'],axis =1, inplace = True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  FWI
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...  ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9  6.5
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2    0
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4  0.2
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1  0.7
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8  0.5
#
# [244 rows x 13 columns]

# %%
df['day']= df['day'].astype(int)
df['month']= df['month'].astype(int)
df['year']= df['year'].astype(int)
df['Temperature']= df['Temperature'].astype(float)
df['RH']= df['RH'].astype(float)
df['Ws']= df['Ws'].astype(float)
df['Rain']= df['Rain'].astype(float)
df['FFMC']= df['FFMC'].astype(float)
df['DMC']= df['DMC'].astype(float)
df['DC']= df['DC'].astype(float)
df['ISI']= df['ISI'].astype(float)
df['BUI']= df['BUI'].astype(float)
df['FWI']= df['FWI'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 10>()
#       8 df['FFMC']= df['FFMC'].astype(float)
#       9 df['DMC']= df['DMC'].astype(float)
# ---> 10 df['DC']= df['DC'].astype(float)
#      11 df['ISI']= df['ISI'].astype(float)
#      12 df['BUI']= df['BUI'].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
df[df['DC']=='14.6 9']
# Out:
#      day  month  year  Temperature    RH    Ws  Rain  FFMC   DMC      DC  \
# 165   14      7  2012         37.0  37.0  18.0   0.2  88.9  12.9  14.6 9
#
#       ISI   BUI      FWI
# 165  12.5  10.4  fire

# %%
df.loc[df['DC'] == '14.6 9', 'DC'] = '14.6'

# %%
df['day']= df['day'].astype(int)
df['month']= df['month'].astype(int)
df['year']= df['year'].astype(int)
df['Temperature']= df['Temperature'].astype(float)
df['RH']= df['RH'].astype(float)
df['Ws']= df['Ws'].astype(float)
df['Rain']= df['Rain'].astype(float)
df['FFMC']= df['FFMC'].astype(float)
df['DMC']= df['DMC'].astype(float)
df['DC']= df['DC'].astype(float)
df['ISI']= df['ISI'].astype(float)
df['BUI']= df['BUI'].astype(float)
df['FWI']= df['FWI'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 13>()
#      11 df['ISI']= df['ISI'].astype(float)
#      12 df['BUI']= df['BUI'].astype(float)
# ---> 13 df['FWI']= df['FWI'].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
df[df['FWI']=='fire   ']
# Out:
#      day  month  year  Temperature    RH    Ws  Rain  FFMC   DMC    DC   ISI  \
# 165   14      7  2012         37.0  37.0  18.0   0.2  88.9  12.9  14.6  12.5
#
#       BUI      FWI
# 165  10.4  fire

# %%
df.loc[ df["FWI"] == 'fire   ', 'FWI'] = '0'

# %%
df['day']= df['day'].astype(int)
df['month']= df['month'].astype(int)
df['year']= df['year'].astype(int)
df['Temperature']= df['Temperature'].astype(float)
df['RH']= df['RH'].astype(float)
df['Ws']= df['Ws'].astype(float)
df['Rain']= df['Rain'].astype(float)
df['FFMC']= df['FFMC'].astype(float)
df['DMC']= df['DMC'].astype(float)
df['DC']= df['DC'].astype(float)
df['ISI']= df['ISI'].astype(float)
df['BUI']= df['BUI'].astype(float)
df['FWI']= df['FWI'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int32
#  1   month        244 non-null    int32
#  2   year         244 non-null    int32
#  3   Temperature  244 non-null    float64
#  4   RH           244 non-null    float64
#  5   Ws           244 non-null    float64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
# dtypes: float64(10), int32(3)
# memory usage: 22.0 KB

# %%
df['year'].unique()
# Out:
# array([2012])

# %%
##as a problem statement we will be predicting temeprature using other features, therfore watching the data the day fetaure and year fetaure will not be much use in training the model, therefore we will drop them

# %%
df.drop(['day','year'],axis=1, inplace= True)

# %%
df
# Out:
#      month  Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI
# 0        6         29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1        6         29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2        6         26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3        6         25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4        6         27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..     ...          ...   ...   ...   ...   ...   ...   ...  ...   ...  ...
# 239      9         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240      9         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 241      9         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242      9         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243      9         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
# [244 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        244 non-null    int32
#  1   Temperature  244 non-null    float64
#  2   RH           244 non-null    float64
#  3   Ws           244 non-null    float64
#  4   Rain         244 non-null    float64
#  5   FFMC         244 non-null    float64
#  6   DMC          244 non-null    float64
#  7   DC           244 non-null    float64
#  8   ISI          244 non-null    float64
#  9   BUI          244 non-null    float64
#  10  FWI          244 non-null    float64
# dtypes: float64(10), int32(1)
# memory usage: 20.1 KB

# %%
df.describe()
# Out:
#             month  Temperature          RH          Ws        Rain  \
# count  244.000000   244.000000  244.000000  244.000000  244.000000
# mean     7.500000    32.172131   61.938525   15.504098    0.760656
# std      1.112961     3.633843   14.884200    2.810178    1.999406
# min      6.000000    22.000000   21.000000    6.000000    0.000000
# 25%      7.000000    30.000000   52.000000   14.000000    0.000000
# 50%      7.500000    32.000000   63.000000   15.000000    0.000000
# 75%      8.000000    35.000000   73.250000   17.000000    0.500000
# max      9.000000    42.000000   90.000000   29.000000   16.800000
#
#              FFMC         DMC          DC         ISI         BUI         FWI
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    77.887705   14.673361   49.288115    4.774180   16.664754    7.006557
# std     14.337571   12.368039   47.619662    4.175318   14.204824    7.438889
# ...

# %%
df.corr()
# Out:
#                 month  Temperature        RH        Ws      Rain      FFMC  \
# month        1.000000    -0.059017 -0.037884 -0.041447  0.035322  0.015577
# Temperature -0.059017     1.000000 -0.654443 -0.278132 -0.326786  0.677491
# RH          -0.037884    -0.654443  1.000000  0.236084  0.222968 -0.645658
# Ws          -0.041447    -0.278132  0.236084  1.000000  0.170169 -0.163255
# Rain         0.035322    -0.326786  0.222968  0.170169  1.000000 -0.544045
# FFMC         0.015577     0.677491 -0.645658 -0.163255 -0.544045  1.000000
# DMC          0.068178     0.483105 -0.405133 -0.001246 -0.288548  0.602391
# DC           0.127672     0.370498 -0.220330  0.076245 -0.296804  0.503910
# ISI          0.061680     0.607551 -0.690637  0.015248 -0.347105  0.739730
# BUI          0.085822     0.455504 -0.348587  0.029756 -0.299171  0.589652
# FWI          0.084201     0.558393 -0.569997  0.028799 -0.322682  0.686033
#
#                   DMC        DC       ISI       BUI       FWI
# ...

# %%
###other ways to see the correlation: Visulaization of correlation

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# We can observe from the above scatter plots that some of the independent variables are not very much correlated (either positively or negatively) with the target variable. These variables will get their coefficients to be reduced in regularization.

# %%
df
# Out:
#      month  Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI
# 0        6         29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1        6         29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2        6         26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3        6         25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4        6         27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..     ...          ...   ...   ...   ...   ...   ...   ...  ...   ...  ...
# 239      9         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240      9         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 241      9         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242      9         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243      9         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
# [244 rows x 11 columns]

# %%
y = df.iloc[:,1]

# %%
y
# Out:
# 0      29.0
# 1      29.0
# 2      26.0
# 3      25.0
# 4      27.0
#        ...
# 239    30.0
# 240    28.0
# 241    27.0
# 242    24.0
# 243    24.0
# Name: Temperature, Length: 244, dtype: float64

# %%
y.values
# Out:
# array([29., 29., 26., 25., 27., 31., 33., 30., 25., 28., 31., 26., 27.,
#        30., 28., 29., 30., 31., 31., 30., 30., 31., 32., 32., 31., 31.,
#        34., 32., 32., 33., 29., 27., 32., 33., 33., 32., 35., 33., 32.,
#        33., 33., 31., 34., 34., 30., 28., 29., 31., 35., 33., 33., 28.,
#        27., 28., 31., 36., 36., 33., 32., 31., 35., 36., 35., 35., 34.,
#        34., 32., 32., 32., 35., 35., 35., 35., 35., 33., 36., 36., 37.,
#        36., 35., 35., 36., 36., 36., 34., 35., 31., 33., 34., 35., 35.,
#        28., 25., 22., 25., 29., 29., 29., 31., 30., 30., 33., 30., 29.,
#        25., 22., 24., 30., 31., 32., 29., 28., 31., 31., 32., 29., 26.,
#        31., 31., 32., 26., 25., 32., 30., 29., 30., 32., 35., 35., 28.,
#        27., 30., 31., 27., 30., 27., 28., 29., 31., 33., 32., 31., 32.,
#        33., 33., 35., 34., 36., 36., 37., 37., 34., 28., 33., 34., 34.,
#        34., 35., 38., 35., 36., 34., 34., 36., 39., 37., 34., 31., 32.,
# ...

# %%
df['temperature']=y.values

# %%
df
# Out:
#      month  Temperature    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0        6         29.0  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1        6         29.0  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2        6         26.0  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3        6         25.0  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4        6         27.0  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..     ...          ...   ...   ...   ...   ...   ...   ...  ...   ...  ...
# 239      9         30.0  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240      9         28.0  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 241      9         27.0  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242      9         24.0  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243      9         24.0  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#      temperature
# 0           29.0
# 1           29.0
# ...

# %%
df.drop(['Temperature'],axis=1, inplace =True)

# %%
df
# Out:
#      month    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  temperature
# 0        6  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5         29.0
# 1        6  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4         29.0
# 2        6  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1         26.0
# 3        6  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0         25.0
# 4        6  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5         27.0
# ..     ...   ...   ...   ...   ...   ...   ...  ...   ...  ...          ...
# 239      9  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5         30.0
# 240      9  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0         28.0
# 241      9  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2         27.0
# 242      9  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7         24.0
# 243      9  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5         24.0
#
# [244 rows x 11 columns]

# %%
##dependent and independent variables
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#      month    RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI
# 0        6  57.0  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1        6  61.0  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2        6  82.0  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3        6  89.0  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4        6  77.0  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..     ...   ...   ...   ...   ...   ...   ...  ...   ...  ...
# 239      9  65.0  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240      9  87.0  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 241      9  87.0  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242      9  54.0  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243      9  64.0  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
# [244 rows x 10 columns]

# %%
y
# Out:
# 0      29.0
# 1      29.0
# 2      26.0
# 3      25.0
# 4      27.0
#        ...
# 239    30.0
# 240    28.0
# 241    27.0
# 242    24.0
# 243    24.0
# Name: temperature, Length: 244, dtype: float64

# %%
##to split the given dataset into train data and test data
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.33, random_state=10)

# %%
x_train.shape
# Out:
# (163, 10)

# %%
x_test.shape
# Out:
# (81, 10)

# %%
y_test.shape
# Out:
# (81,)

# %%
y_train.shape
# Out:
# (163,)

# %%
## Standardize or feature scaling                              ##this helps in easier calculation of gradient descent and reaching to global minima is also easy
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.33562856, -0.85631108, -3.36419461, ..., -0.9695694 ,
#         -0.32535487, -0.85589384],
#        [ 0.44338489, -0.52508491,  0.99944243, ...,  1.17918645,
#          0.76565444,  1.21984339],
#        [-1.34110244,  0.13736742,  0.99944243, ...,  0.4708054 ,
#          0.35302912,  0.4926743 ],
#        ...,
#        [ 1.33562856, -0.72382061, -0.81873967, ...,  0.5180308 ,
#          0.08727045,  0.38690425],
#        [-1.34110244,  0.13736742, -0.45510325, ..., -0.59176617,
#         -0.76595478, -0.7765663 ],
#        [-1.34110244,  1.13104591, -1.18237609, ..., -0.80428049,
#         -0.27639932, -0.78978756]])

# %%
x_test
# Out:
# array([[-4.48858777e-01, -3.92594448e-01, -9.14668296e-02,
#          1.48701853e+00, -1.82411230e-01, -6.02677495e-01,
#         -8.21325921e-01, -7.33442383e-01, -6.82030988e-01,
#         -8.03008814e-01],
#        [-4.48858777e-01,  1.37367416e-01,  6.35806011e-01,
#         -4.41414004e-01,  6.64566895e-01,  1.37979749e+00,
#          2.03374779e+00,  4.94418103e-01,  1.72378441e+00,
#          1.16695836e+00],
#        [ 4.43384889e-01, -1.12129201e+00, -4.55103250e-01,
#         -4.41414004e-01,  9.08075201e-02, -7.86536062e-01,
#         -8.06652268e-01, -6.38991577e-01, -8.28897625e-01,
#         -7.89787558e-01],
#        [ 4.43384889e-01,  7.11221826e-02, -4.55103250e-01,
#         -2.41920984e-01, -5.94627923e-02, -7.14591405e-01,
#         -8.10844740e-01, -7.09829682e-01, -7.72948430e-01,
#         -8.03008814e-01],
#        [ 4.43384889e-01, -1.93858749e-01,  6.35806011e-01,
#         -4.41414004e-01,  6.78227832e-01,  1.28490116e-02,
# ...

# %% [markdown]
# # Model training

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
## Next, train the model using the training sets as follows −
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [-0.29751556 -1.18873402 -0.60249416 -0.15940727  1.05744745  0.44676044
#   0.89431166  0.51890118 -0.77777776 -0.3215604 ]

# %%
print(regression.intercept_)
# Out:
# 32.17791411042945

# %%
## make predictions using the testing set as follows −
reg_pred=regression.predict(x_test)

# %%
reg_pred
# Out:
# array([31.80764977, 33.51403169, 33.31380133, 31.65800448, 32.90945406,
#        34.81759685, 34.02512799, 33.71269484, 32.19592005, 33.24031689,
#        33.75993752, 27.2407738 , 35.06272277, 29.16882789, 32.01288677,
#        32.26713928, 34.35799234, 27.64431882, 36.06321622, 34.38938394,
#        33.22463927, 33.93037934, 34.12425204, 33.20186196, 35.93556606,
#        29.16948151, 32.25274831, 32.63991051, 27.19867146, 32.49967514,
#        25.70296923, 26.23554056, 34.53074759, 32.09285606, 33.43527696,
#        30.06369697, 29.36715671, 32.02217789, 27.22820116, 35.72212717,
#        32.62935441, 34.14892573, 34.26037736, 30.76389957, 36.38016466,
#        34.08464366, 25.11286351, 35.12207493, 34.16509765, 29.33267836,
#        31.67667331, 32.70723661, 35.47963395, 32.58905135, 29.96774676,
#        29.89298217, 32.52679938, 36.50047464, 31.35764508, 33.07141897,
#        32.52758265, 33.0156361 , 31.494446  , 25.29430415, 31.46457705,
# ...

# %%
## Looking into the assumptions of linear regression

# %%
plt.scatter(y_test,reg_pred)
plt.xlabel("Test Truth Data")
plt.ylabel("Test predicted Data")
# Out:
# Text(0, 0.5, 'Test predicted Data')

# %%
residuals=y_test-reg_pred

# %%
sns.displot(residuals,kind="kde")

# %%
plt.scatter(reg_pred,residuals)

# %%
## found that it does not follow the assumptions,, but we already knew as this dataset's actual target variable was categprical, we are just practicing the application of linear, ridge, lasso, net elastic regression.

# %% [markdown]
# ## Performance matrics

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test, reg_pred))
print(mean_absolute_error(y_test, reg_pred))
print(np.sqrt(mean_squared_error(y_test, reg_pred)))
# Out:
# 6.567179427678385
# 2.13406240781451
# 2.5626508594965456

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.5657313771190924

# %%
## Adjusted R square
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.5036930024218198

# %% [markdown]
# ## Ridge regression

# %%
from sklearn.linear_model import Ridge

# %%
rregression = Ridge(alpha = 0.5, normalize = False, tol = 0.001, 
              solver ='auto', random_state = 42)
rregression.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.5, normalize=False, random_state=42)

# %%
print(rregression.coef_)
# Out:
# [-0.29263762 -1.19172909 -0.60161012 -0.16460215  1.04685332  0.24809784
#   0.77384761  0.50976612 -0.46329275 -0.31690227]

# %%
print(rregression.intercept_)
# Out:
# 32.17791411042945

# %%
rreg_pred=rregression.predict(x_test)

# %%
rreg_pred
# Out:
# array([31.80790359, 33.5311614 , 33.31516154, 31.660742  , 32.91108376,
#        34.84371815, 34.00996437, 33.67839636, 32.19150487, 33.23069249,
#        33.74221626, 27.25244446, 35.05462712, 29.15933085, 32.01276056,
#        32.25652279, 34.34633433, 27.66878243, 36.0679841 , 34.38895792,
#        33.21827173, 33.91443449, 34.12263658, 33.18994778, 35.92584833,
#        29.16706277, 32.22210008, 32.65737704, 27.21685753, 32.5108509 ,
#        25.70607421, 26.26130714, 34.51299175, 32.09430756, 33.42989288,
#        30.06842452, 29.35629752, 32.02168631, 27.2500497 , 35.72301019,
#        32.63670771, 34.13338158, 34.2609356 , 30.75936267, 36.37108843,
#        34.0873624 , 25.09420737, 35.12700237, 34.15736894, 29.33344383,
#        31.66421284, 32.70237134, 35.48998836, 32.57760762, 29.97295545,
#        29.88497042, 32.53818776, 36.50470816, 31.35548315, 33.06569524,
#        32.52826506, 33.02445843, 31.49147103, 25.26341609, 31.47564687,
# ...

# %%
print(mean_squared_error(y_test, rreg_pred))
print(mean_absolute_error(y_test, rreg_pred))
print(np.sqrt(mean_squared_error(y_test, rreg_pred)))
# Out:
# 6.577231136179678
# 2.134536842112287
# 2.564611303137315

# %%
from sklearn.metrics import r2_score
rscore=r2_score(y_test,rreg_pred)
print(rscore)
# Out:
# 0.5650666866448137

# %%
## Adjusted R square
#display adjusted R-squared
1 - (1-rscore)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.5029333561655014

# %% [markdown]
# ## Lasso regression

# %%
# import Lasso regression from sklearn library
from sklearn.linear_model import Lasso

# %%
# Train the model
lregression = Lasso(alpha = 1)
lregression.fit(x_train, y_train)
lasoreg_pred = lregression.predict(x_test)

# %%
lasoreg_pred
# Out:
# array([32.29700076, 32.6744027 , 33.06609539, 32.07346965, 32.92497671,
#        33.33947653, 33.32111992, 32.77042154, 32.11916885, 32.70983221,
#        33.15976154, 30.29861247, 34.17172792, 30.95174825, 33.0931383 ,
#        32.31497272, 32.93691477, 29.42489766, 34.46059856, 33.50695377,
#        32.46152593, 33.02899752, 33.30888217, 32.80645043, 34.5498142 ,
#        30.18680443, 32.38908351, 32.89121556, 29.47641605, 31.8492542 ,
#        29.50217524, 28.6091198 , 33.21226395, 32.70054654, 32.64380834,
#        31.80937418, 30.23515603, 32.53110125, 29.22810977, 33.62676377,
#        32.55104126, 33.23190428, 33.93112391, 31.84411936, 34.06445535,
#        33.20742879, 29.78847846, 33.80519505, 33.21966653, 30.53913152,
#        31.62769114, 32.373594  , 33.92016988, 32.24993288, 31.51301599,
#        31.26381066, 32.303719  , 34.28571873, 31.84095256, 33.47507571,
#        32.27184094, 32.20868418, 31.42230192, 29.36272493, 32.24706577,
# ...

# %%
lregression.coef_
# Out:
# array([-0.        , -0.71955751, -0.        , -0.        ,  0.89582004,
#         0.        ,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
# Calculate performance metrices
print(mean_squared_error(y_test, lasoreg_pred))
print(mean_absolute_error(y_test, lasoreg_pred))
print(np.sqrt(mean_squared_error(y_test, lasoreg_pred)))
# Out:
# 9.10609532182792
# 2.4978660766652743
# 3.0176307464346794

# %%
from sklearn.metrics import r2_score
lasoscore=r2_score(y_test,lasoreg_pred)
print(lasoscore)
# Out:
# 0.39784019626969913

# %%
## Adjusted R square
#display adjusted R-squared
1 - (1-lasoscore)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.31181736716537045

# %% [markdown]
# ## Elastic Net

# %%
# import model
from sklearn.linear_model import ElasticNet

# %%
# Train the model
e_net = ElasticNet(alpha = 1)
e_net.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=1)

# %%
# calculate the prediction
enreg_pred = e_net.predict(x_test)

# %%
# calculating the performace matrices
print(mean_squared_error(y_test, enreg_pred))
print(mean_absolute_error(y_test, enreg_pred))
print(np.sqrt(mean_squared_error(y_test, enreg_pred)))
# Out:
# 8.305567344790521
# 2.389961462960389
# 2.881938122998223

# %%
from sklearn.metrics import r2_score
enscore=r2_score(y_test,enreg_pred)
print(enscore)
# Out:
# 0.4507768010928398

# %%
## Adjusted R square
#display adjusted R-squared
1 - (1-enscore)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# 0.3723163441061027
